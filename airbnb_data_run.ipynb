# %% [markdown]
# <a href="https://colab.research.google.com/github/swbgibbons/cal_trac/blob/main/airbnb_data_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
airbnb_data = pd.read_csv('/content/archive.zip', low_memory=False)
airbnb_data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
airbnb_data.shape
# Out:
# (102599, 26)

# %%
airbnb_data.rename(columns={'host_identity_verified': 'verified'}, inplace=True)
airbnb_data.head()

# %%
# return data series where 
verified = airbnb_data[airbnb_data['verified'] == 'verified']
verified

# %%
verified.columns
# Note: specific index ranges are as follows
# [0:2, 4:6, 9:13, 15:25]
# Out:
# Index(['id', 'NAME', 'host id', 'verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'lat', 'long', 'country', 'country code',
#        'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
new_df = verified[['id', 'NAME', 'host id', 'host name', 'neighbourhood group', 'neighbourhood', 'country', 'country code',
                'instant_bookable', 'price', 'service fee', 'minimum nights', 'number of reviews', 'last review',
                'reviews per month', 'review rate number', 'calculated host listings count', 'availability 365',
                'house_rules', 'license']]
new_df.head()
# Out:
#          id                                              NAME      host id  \
# 1   1002102                             Skylit Midtown Castle  52335172823
# 4   1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5   1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 8   1005754                   Large Furnished Room Near B'way  79384379533
# 10  1006859                Cute & Cozy Lower East Side 1 bdrm   1280143094
#
#    host name neighbourhood group   neighbourhood        country country code  \
# 1      Jenna           Manhattan         Midtown  United States           US
# 4     Lyndon           Manhattan     East Harlem  United States           US
# 5   Michelle           Manhattan     Murray Hill  United States           US
# 8     Evelyn           Manhattan  Hell's Kitchen  United States           US
# 10   Miranda           Manhattan       Chinatown  United States           US
#
# ...

# %%
import numpy as np
loki = verified.iloc[:,np.r_[0:2, 4:6, 9:13, 15:25]]
loki.head()
# Out:
#          id                                              NAME host name  \
# 1   1002102                             Skylit Midtown Castle     Jenna
# 4   1003689  Entire Apt: Spacious Studio/Loft by central park    Lyndon
# 5   1004098         Large Cozy 1 BR Apartment In Midtown East  Michelle
# 8   1005754                   Large Furnished Room Near B'way    Evelyn
# 10  1006859                Cute & Cozy Lower East Side 1 bdrm   Miranda
#
#    neighbourhood group        country country code instant_bookable  \
# 1            Manhattan  United States           US            False
# 4            Manhattan  United States           US            False
# 5            Manhattan  United States           US             True
# 8            Manhattan  United States           US             True
# 10           Manhattan  United States           US            False
#
#    cancellation_policy    price service fee  minimum nights  \
# ...

# %%
# new function alert!
# using the 'np.r_' to parse thru specific indices is fucking KING BBY

# %%
# instant_bookable = True,
# 	cancellation policy is moderate or flexible,
# 	service fee doesnt exceed $35,
# 	minimum nights less than 10

# %%
versa = loki[loki[['instant_bookable' == 'True'], loki['cancellation_policy' == 'moderate' or 'flexible']]
versa
# Out:
#   File "<ipython-input-38-7b1cc825aa29>", line 2
#     versa
#         ^
# SyntaxError: invalid syntax

# %%
versa = loki[(loki['instant_bookable']), (loki['cancellation_policy'] == 'moderate' | 'flexible')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-7d61ba705f34> in <module>()
# ----> 1 versa = loki[(loki['instant_bookable']), (loki['cancellation_policy'] == 'moderate' | 'flexible')]
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
